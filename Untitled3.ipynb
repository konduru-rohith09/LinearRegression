# %% [markdown]
#  **Math Behind The Linear Regression**

# %% [markdown]
# **FORMULA**
#
#
# y = mx + c
#
# 1. y is a dependent variable and (output/ predicted value).
#
# 2. x is a independent variable (Input value).
#
# 3. m is a slopen (regression coefficient)
#    Tells how much y changes whe  x increases by 1.
#
# 4. c id intercept
#    value of y when x=0.

# %% [markdown]
# ![linear regression.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# example:
#
#       you are predicting a home price based on the room
#
#        x-> size of room
#
#        y-> price
#
# Based on the picture random data points are there based on that i drawn a best fit line and starting of the line my c point is there because in that time my m=0 and see the line above and below some datapoints are there that data points are mistakes and errors. It shown hoe far the line is from real value.
#
#
#
# We have a written near thge line:
#
# 1. 1000
#
# 2. 1100
#
# the difference between them is  the error.
#
# error= 1100 - 1000 = 100
#
#
# for example : your house price is 1000 but model predictes 1100.The error is 100

# %% [markdown]
# **Minimize the error**
#
# To minimize the error we use cost function.
#
# Small cost : good line
#
# Big cost   : bad line
#
# regression job is to make this cost as amall as possible
#
#
#
# ![cost function.jpeg](data:image/jpeg;base64,...)
#
#
# It measures how wrong your predictions are, on average.
#
# (y-y)^2  tells that error between the predcition and reality
#
#
# 1/2m: m takes a average error and 2 makes differentiantion easier when finding optimal m and c

# %% [markdown]
# **How to draw the line**
#
#
# ![cost function.jpeg](data:image/jpeg;base64,...)
#
#
# above the Diagram of how to draw a line:
#
# formula is Y = mx + c
#
# my c is 0 here
#
# assume my m is 1 and my input is 1
#
# y=mc
#
# y=(1)(1) = 1 so that why the point is on 1.
#
# same as 2 and 3 but m is constant here.
#
#
# we have multiple lines to draw the best fit line.
#
# here my c is 0 but sometimes c is different that time best fit line will change.

# %% [markdown]
# **We use the gradient descent to draw the best fit line.**
#
#
#
#
# gradient descent dosen't literally draw the line at once. It slowly improves the line until it becomes the best fit line.
#
# ![cost function.jpeg](data:image/jpeg;base64,...)
#
#
# x-axis -> model parameter (like m , slope)
#
# y-axis -> cost / error (how wrong the model is)
#
# that is the error curve. The curve is like a bowl / valley
#
# The circled lowest point is GLOBAL MINIMUM. This is where the error is smallest possible.
#
# that curve indicates which direction will reduce error?
#
# if slope is posstitive(+ve) -> move left.
# if slope is negative(-ve) -> move right.
#
# always move downhill.
#
# convergence theorem:
#
# it will help to reach the minimum and stop.The slope of the curve is almost 0  you are at the minimum point.and cost stop decreasing and you reached the best fit line
