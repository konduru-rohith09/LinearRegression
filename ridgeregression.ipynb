# %% [markdown]
# **Ridge Regresion**
#
# Ridge regression is a linear regression technique that adds a penalty on large coefficients to reduce overfitting.
#
# **Overfitting**
#
# If a model fits training data very well but fails to generalize  to test data, it is overfitting.
#
#
#
# ![cost function.jpeg](data:image/jpeg;base64,...)
#
#
# In this picture the straight line is model trained on the training data very well. When it comes to the testing data there is a huge difference between them.If the model perform poorly on test data predictions are far from away.We have to reduce that line until it becomes approximately zero not exactly zero.
#
# **Why exactly not zero?**
#
# Because in real world data:
#
# 1. noise exists
# 2. measurement error exist
# 3. data is not perfectly linear
#
# so even very complex model cannot make zero, But it can make approximately zero.

# %% [markdown]
# **Reduce the overfitting:**
#
# ![cost function.jpeg](data:image/jpeg;base64,...)
#
#
# In the above picture shows the reducing the overfiting line.
#
# the formula is cost function + lambda  multiply (slope)^2
#
# The cost function is to make the best fit line.after evaluating the test data the model becomes poor.
#
# In the diagram 1st line is my best line after evaluating test data becomes poor.In my second line i reduced my slope after calculating better than the first line so 2nd line is my 2nd line and the 3rd line is approximately zero.
#
# Here:
#
# The mail goal is to shrink the slope towards zero not exacly zero.
#
#
# After the third line if you evaluate the train data into your test data the model predicts good.
#
#
# overfitting = converting high variance to low variance
