# %% [markdown]
# **Lasso Regression:**
#
# ![cost function.jpeg](data:image/jpeg;base64,...)
#
#
#
# In lasso regression we use magnitude of slope |slope|. Lasso regression just not help in overfitting but alos it helps us to do feature selection

# %% [markdown]
# **Example:**
#
#
# suppose i have multiple features:
#
# ![cost function.jpeg](data:image/jpeg;base64,...)
#
#
# In this case the slope  move to zero, so wherever the slope value is very very less that feature will be removed.Measn that feature is not important to predict our best fit line so this entire process is our feature selection
